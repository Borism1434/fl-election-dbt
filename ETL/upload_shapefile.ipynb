# %%
from db import execute_sql

execute_sql("CREATE EXTENSION IF NOT EXISTS postgis;")

# %%
from db import get_engine
import geopandas as gpd

engine = get_engine()

gdf = gpd.read_file("/Users/borismartinez/Downloads/ZipcodeMailingCity_gdb_-5930403427836655181 (1)/ZipcodeMailingCity.shp")
 # gdf.head()
max_lengths = gdf.astype(str).applymap(len).max()
print(max_lengths)
# Out:
# ZIP               5
# ZIPCODE           5
# MAILING_MU       20
# GlobalID         36
# geometry      94719
# dtype: int64
# /var/folders/h3/qc0834sx6gjb7174_439hbkc0000gn/T/ipykernel_80587/2648550678.py:8: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   max_lengths = gdf.astype(str).applymap(len).max()

# %%
gdf.to_postgis(name="zipcode_mailing_city", con=engine, schema="geo", if_exists="replace", index=False)
