# %% [markdown]
# ## Overview `process_directories()`
#
# This script automates the process of merging `.txt` files from two user-specified directories into a single file per directory and then moves the merged files into a `final` directory. The script is structured into two main functions:
#
# `merge_txt_files(directory)` – Merges all `.txt` files in a given directory into a single output file.
#
# `process_directories()` – Prompts the user for two directory paths, processes them using `merge_txt_files()`, and moves the merged files to a `final` directory.

# %%
import os 
import shutil

def merge_txt_files(directory):
    """
    Merge all .txt files within the given directory into a single file
    and saves the output file inside the same directory. 
    """
    try:
        print(f"Processing Directory: {directory}")

        # Validate if the directory exists
        if not os.path.isdir(directory):
            print(f"Error: The provided path is not a valid directory: {directory}")
            return None
        print("Directory Exists! Proceeding...")
        
        # Get the Directory name for naming the output file
        directory_name = os.path.basename(os.path.normpath(directory))
        output_filename = os.path.join(directory, f"{directory_name}_combined_date.txt")

        # Initialize an empty list to store .txt filename
        txt_files = []

        # Loop through files in the directory and collect .txt files
        for file_name in os.listdir(directory): 
            if file_name.endswith(".txt"):
                txt_files.append(file_name) 
                
            # Check if there are any .txt files 
        if not txt_files:
            print({f"No .txt files found in {directory}"})
            return None
        
        print(f"Found {len(txt_files)} .txt files, merging ...")

        # Open the output file in write mode
        with open(output_filename, "w", encoding="utf-8") as outfile:
            for txt_file in txt_files:
                file_path = os.path.join(directory, txt_file)

                # Open each text file and append its content 
                with open(file_path, "r", encoding="utf-8") as infile:
                    for line in infile:
                        outfile.write(line) # write each line
                    # outfile.write("\n") # Add a newline for separation
        return output_filename # return the merged file path  for later use 
    except Exception as e:
        print(f"Error: {e}")
        return None
    
def process_directories(): 
    """ 
    Prompts the user for two directory path in a single input, 
    merges their text files separetely, and moves the final merged files into a 'final' directory. 
    """
    try: 
        # Ask user for both directories in one input (separated by space)
        directory_input = input("Enter the two directory paths (separated by a space): ").strip()
        
        # Split input into two directory paths 
        directories = directory_input.split(maxsplit=1)

        # Ensure exactly two directories are provided
        if len(directories) != 2:
            print("Error: Please provided exactly two directory path separated by a space.")
            return
        
        dir1, dir2 = directories # Extract Directories 
        
        # Merge Files for both directories
        merged_file1 = merge_txt_files(dir1)
        merged_file2 = merge_txt_files(dir2)

        # Create "final" directory if it dosen't exist
        final_dir = os.path.join(os.path.dirname(dir1), "final")
        os.makedirs(final_dir, exist_ok=True)
        # Move merged files to "final" dir if they exist
        if merged_file1:
            shutil.move(merged_file1, os.path.join(final_dir, os.path.basename(merged_file1)))
            print(f"Moved {os.path.basename(merged_file1)} to {final_dir}")
        
        if merged_file2:
            shutil.move(merged_file2, os.path.join(final_dir, os.path.basename(merged_file2)))
            print(f"Moved {os.path.basename(merged_file2)} to {final_dir}")
        print("All processing completed successfully!")
    except Exception as e:
        print(f"Erorr: {e}")
# Run the full process
process_directories()
# Out:
# Processing Directory: /Users/borismartinez/Documents/VoterHistory
# Directory Exists! Proceeding...
# Found 67 .txt files, merging ...
# Processing Directory: /Users/borismartinez/Documents/VoterRegistration
# Directory Exists! Proceeding...
# Found 66 .txt files, merging ...
# Moved VoterHistory_combined_date.txt to /Users/borismartinez/Documents/final
# Moved VoterRegistration_combined_date.txt to /Users/borismartinez/Documents/final
# All processing completed successfully!

# %% [markdown]
# ## Overview `connect_to_db()`
#
# This script establishes a connection to a PostgreSQL database using psycopg2. It defines the database parameters (name, user, password, host, port) and a function `connect_to_db()`, which attempts to connect to the database, returning a connection (conn) and cursor (cur) if successful. If the connection fails, it prints an error and returns None, None. Finally, it calls `connect_to_db()` to test the connection and prints a confirmation message if successful.

# %%
import psycopg2
import os 


# Database connection parameters 
db_name = "fl_election"
db_user = "postgres"
db_password = "1434"
db_host = "192.168.86.23" # Change to server's IP when acessing remotely
db_port = "5432"

def connect_to_db():
    """ Establish a connection to PostgreSQL and return the connection & cursor. """
    
    try:
        print("Attempting to connect...")
        conn = psycopg2.connect(
            dbname = db_name,
            user = db_user,
            password = db_password,
            host = db_host,
            port = db_port
        )
        cur = conn.cursor()
        print("Connected to PostgreSQL")
        return conn, cur
    except Exception as e:
        print(f"Database connection error: {e}")
        return None, None
    
# Call the function to test connection
conn, cur = connect_to_db()
# Out:
# Attempting to connect...
# Connected to PostgreSQL

# %% [markdown]
# # Overview Table Creation
#
# This script connects to a PostgreSQL database and ensures that a table named test inside the voterfile schema exists. It:\
# 	1.	Connects to the database using connect_to_db().\
# 	2.	Checks if the connection is successful (if conn:).\
# 	3.	Attempts to create the table with predefined columns and data types using CREATE TABLE IF NOT EXISTS.\
# 	4.	Commits changes to make sure the table is saved.\
# 	5.	Handles errors if the table creation fails (except Exception as e).

# %%
conn, cur = connect_to_db()

if conn:
    try:
        # Change 'user_table' to your actual table name
        cur.execute("""
            create table if not exists voterfile.election_history_2016_test (
                county varchar(25),
                voter_id int,
                election_code varchar(6),
                vote_date varchar(10),
                vote_history_code varchar(1),
                precinct varchar(6),
                congressional_district varchar(3),
                house_district varchar(3),
                senate_district varchar(3),
                county_commission_district varchar(3),
                school_board_district varchar(2)
            );
        """)
        conn.commit()
        print("Table created successfully!")
    except Exception as e:
        print(f"Error creating table: {e}")
    finally:
        cur.close()
        conn.close()
# Out:
# Attempting to connect...
# Connected to PostgreSQL
# Table created successfully!

# %% [markdown]
# # Voterfile ETL Pipline
#
# This script processes and uploads tab-delimited voter data to a PostgreSQL database.
#
# Step 1: Extract Table Schema (get_table_columns)
# 	•	Connects to the database and retrieves column names, data types, and character limits for a given table.
# 	•	Stores columns as:
# 	•	List (columns) – Stores all column names.
# 	•	Set (date_columns) – Tracks date columns.
# 	•	Set (int_columns) – Tracks integer columns.
# 	•	Dictionary (char_limits) – Stores VARCHAR max lengths.
#
# Step 2: Data Cleaning (clean_value)
# 	•	Removes extra spaces and converts empty values to None.
# 	•	Ensures:
# 	•	Dates are properly formatted (YYYY-MM-DD).
# 	•	Integer values are valid (non-numeric values become None).
# 	•	Text fields do not exceed database column limits.
#
# Step 3: Read, Clean, and Save Data (preprocess_and_save_cleaned_file)
# 	•	Reads tab-delimited text files and processes each row.
# 	•	Skips malformed rows where column count doesn’t match.
# 	•	Cleans each value using `clean_value()`, then writes cleaned data to a new `.txt` file.
#
# Step 4: Upload to PostgreSQL (upload_txt_postgres)
# 	•	Validates file existence before proceeding.
# 	•	Calls `get_table_columns()` to dynamically fetch schema details.
# 	•	Cleans and saves the file before using PostgreSQL COPY for fast bulk insertion.
# 	•	Manages database connections properly with try/except/finally.

# %%
import csv 
import os 


def get_table_columns(table_name): 
    """ Fetches the column names for a given table from PostgreSQL."""
    conn, cur = connect_to_db()

    if not conn:
        print("Database connection failed. Connect fetch table columns.")
        return None, None, None
    
    try: 
        full_table_name = f"voterfile.{table_name}"

        cur.execute(f"""
                    select column_name, data_type, character_maximum_length
                    from information_schema.columns
                    where table_schema = 'voterfile' and table_name = '{table_name}'
                    order by ordinal_position;
                    """)
        
        # Initialize List, set, set, dictionary 
        columns = []
        date_columns = set()
        int_columns = set()
        char_limits = {}
        
        for column_name, data_type, char_max_length in cur.fetchall():
            columns.append(column_name)
            
            # Identify Date Columns
            if data_type.lower() == "date":  
                date_columns.add(column_name)
            
            # Identify Integer Columns
            if "int" in data_type.lower():
                int_columns.add(column_name)
            
            # Store character limits (for VARCHAR columns)
            if char_max_length is not None:
                char_limits[column_name] = char_max_length  # Store the max length

        if not columns:
            print(f"Error: Table '{full_table_name} does not exist or has no columns.")
            return None, None, None, None
        
        print(f"Retrieved {len(columns)} columns for table '{full_table_name}'.")
        return columns, date_columns, int_columns, char_limits
    
    except Exception as e: 
        print("Error fetching columns: {e}")
        return None, None, None, None
    
    finally:
        cur.close()
        conn.close()


def clean_value(value, column_name, date_columns, int_columns, char_limits):
    """ Cleans a single value by converting '*' and empty strings to None (Null in PostgreSQL). """
    value = value.strip() # remove leading/trailing space 

    # Convert '*' or empty fields to None (Null in PostgreSQL)
    if value in ["", "*"]:
        return None

   # Check if the column is a DATA type
    if column_name in date_columns: # Identify data columns 
        try:
            parts = value.split("/") 
            if len(parts) == 3: # Expected mm/dd/yyyy format
                month, day, year = parts 
                formatted_date = f"{year}-{month.zfill(2)}-{day.zfill(2)}"
                return formatted_date  # Convert to YYYY-MM-DD
            else: 
                return None # Invalid date 
        except:
            return None
        
    # Convert empty strings to None for integer columns
    if column_name in int_columns:
        if not value.isdigit():  # Ensure value is numeric
            return None
        return int(value)  # Convert valid numeric strings to integers
    
    # Handle Character Limit (Trim oversized values)
    if column_name in char_limits:
        max_length = char_limits[column_name]
        if len(value) > max_length:
            print(f"Truncating '{column_name}' from {len(value)} to {max_length} chars: {value}")
            return value[:max_length]  # Trim to max length

    return value


def preprocess_and_save_cleaned_file(file_path, cleaned_file_path, table_columns, date_columns, int_columns, char_limits):
    """ Reads, cleans, and saves a cleaned version for COPY. """

    with open(file_path, "r", encoding="utf-8") as infile, \
        open(cleaned_file_path, "w", encoding="utf-8", newline="") as outfile:
        reader = csv.reader(infile, delimiter="\t") #tab-delimited file 
        writer = csv.writer(outfile, delimiter="\t", quoting=csv.QUOTE_MINIMAL) # Keep tab format

        for row in reader: 
            # Skip malformed rows 
            if len(row) != len(table_columns):
                print(f"Skipping malformed row (expected {len(table_columns)}, got {len(row)}): {row}")
                continue

            # Clean row before writing 
            # Need revert List Comprehension
            cleaned_row = [clean_value(value, table_columns[i], date_columns, int_columns, char_limits) for i, value in enumerate(row)]
            
            # Write to cleaned file (Ensure NULL values are explicitly written)
            writer.writerow(["NULL" if v is None else v for v in cleaned_row])

    print(f"Cleaned file saved at: {cleaned_file_path}")
    return cleaned_file_path # Return cleaned file path


def upload_txt_postgres(file_path, table_name = "election_detail_2016"):
    """ Uploads a tab-delimited .txt file into a PostgreSQL table inside the 'voterfile' schema. """

    if not os.path.exists(file_path):
        print(f"Error: The file '{file_path}' does not exist.")
        return
    
   # Fetch table columns & date columns dynamically
    table_columns, date_columns, int_columns, char_limits = get_table_columns(table_name)

    if not table_columns:
        print("Could not retrieve table columns. Aborting upload.")
        return
    
    # Save cleaned data for COPY
    cleaned_file_path = file_path.replace(".txt", "_cleaned.txt")
    cleaned_file_path = preprocess_and_save_cleaned_file(
        file_path, cleaned_file_path, table_columns, date_columns, int_columns, char_limits
    )  

   # Connect to PostgreSQL using the existing function 
    conn, cur = connect_to_db()

    if not conn:
        print("Database connection failed. Aborting upload.")
        return 
    
    try:
        print(f"Connected to PostgreSQL. Uploading '{file_path}' to 'voterfile.{table_name}'.")

        # Ensure table name uses correct schema 
        full_table_name = f"voterfile.{table_name}"

        copy_query = f"""
            COPY {full_table_name} from STDIN
            with (format csv, delimiter E'\t', NULL 'NULL');
        """

        with open(cleaned_file_path, "r", encoding="utf-8") as f:
            cur.copy_expert(copy_query, f)

        conn.commit()
        print(f"Successfully uploaded data from '{cleaned_file_path}' using COPY.")

    except Exception as e:
        print(f"Error uploading file: {e}")
    
    finally:
        cur.close()
        conn.close()
        print("Database connection closed.")

file_path = "/Users/borismartinez/Documents/final/VoterRegistration_combined_date.txt"
upload_txt_postgres(file_path)
# Out:
# Attempting to connect...
# Connected to PostgreSQL
# Retrieved 46 columns for table 'voterfile.election_detail_2016'.
# Truncating 'former_name' from 31 to 30 chars: Barbara Geneva Hankerson Dolsin
# Truncating 'former_name' from 31 to 30 chars: Craig Jonathan Wilkerson Padron
# Truncating 'former_name' from 32 to 30 chars: Joyce Giordana Martinez-Martinez
# Truncating 'former_name' from 31 to 30 chars: Natalie Sherell Thomas-Darrisaw
# Truncating 'former_name' from 31 to 30 chars: Margaret Kendall Powell Lutkins
# Truncating 'former_name' from 31 to 30 chars: COURTNEY VALERIE EASTMAN WILKIN
# Truncating 'former_name' from 32 to 30 chars: Constance Lorraine Staffeld Dean
# Truncating 'former_name' from 33 to 30 chars: Keiondra Auntquayeyateas Williams
# Truncating 'former_name' from 31 to 30 chars: Christopher Michael Stonecipher
# Truncating 'former_name' from 33 to 30 chars: Elizabeth Williams Twohy Westover
# Truncating 'former_name' from 32 to 30 chars: CHRISTINA DENISE CONTRERAS BERRY
# Truncating 'former_name' from 31 to 30 chars: MARQUISEANNE LEVONNE WILLIAMSON
# Truncating 'former_name' from 35 to 30 chars: Maximillion Alexander Joseph Lipkin
# Truncating 'former_name' from 33 to 30 chars: Myriam Belisse Castellano Barreto
# Truncating 'former_name' from 32 to 30 chars: Roslyn Condenisia Tyteon Sanders
# Truncating 'former_name' from 31 to 30 chars: Patrecia May Filippone Sinclair
# Truncating 'former_name' from 33 to 30 chars: CHIQUETTA JIM-MECIKKAVONT JOHNSON
# Truncating 'former_name' from 31 to 30 chars: SHANDERA YVONNE BARNES-WHITAKER
# Truncating 'former_name' from 33 to 30 chars: DAHLIA JANICE FULGENCE CHALLENGER
# Truncating 'former_name' from 34 to 30 chars: TRESHANDRA RANEKEA  WILLIAMS-TYSON
# Truncating 'former_name' from 34 to 30 chars: XAVEIRA CANESHIA NAQUANNA WHETSTON
# Truncating 'former_name' from 32 to 30 chars: LA'DERRION DANQUALE ZARON CHUKES
# Truncating 'former_name' from 31 to 30 chars: Christina Malicia Esther Wilson
# Truncating 'former_name' from 32 to 30 chars: Manuel Vincente Angulo Rodriguez
# Truncating 'former_name' from 32 to 30 chars: Tiffany Arnetia Barrett-Robinson
# Truncating 'former_name' from 31 to 30 chars: Brenda Louise Harrison Mcarthur
# Truncating 'former_name' from 34 to 30 chars: Allyson Nichole Cummings Varnadore
# Truncating 'former_name' from 34 to 30 chars: MARIA REBECCA REYES VILLA-MOSQUEDA
# Truncating 'former_name' from 32 to 30 chars: MARJA KRISTIINA BAESZLER-CHIAMPO
# Truncating 'former_name' from 31 to 30 chars: Latisha Althea Williams-Settles
# Truncating 'former_name' from 31 to 30 chars: Cintia Anabel Reichert-Guanchez
# Truncating 'former_name' from 31 to 30 chars: Chantell Nacole Regean Copeland
# Truncating 'former_name' from 37 to 30 chars: Katrina Roxanne Marie Domingo Verzosa
# Truncating 'former_name' from 31 to 30 chars: JOAN SEBASTIAN RODRIGUEZ SUAREZ
# Truncating 'former_name' from 40 to 30 chars: JACQUELINE CRISTENE CRISOST OMO VAN GEME
# Truncating 'former_name' from 32 to 30 chars: CASIMER LAWRENCE DAIVD HENDERSON
# Truncating 'former_name' from 31 to 30 chars: Jose Abraham Sandoval Catarineu
# Truncating 'former_name' from 33 to 30 chars: Mary Caroline Mcconathy-Schneider
# Truncating 'former_name' from 31 to 30 chars: Victoria Lynn Guarriello Medlin
# Truncating 'former_name' from 31 to 30 chars: Amparo Sunshine Lara De La Riva
# Truncating 'former_name' from 31 to 30 chars: Jacqueline Isabel-Nicole Saguin
# Truncating 'former_name' from 36 to 30 chars: Shoshanna Rothier Chanock Wiercinski
# Truncating 'former_name' from 33 to 30 chars: Theresa Louise Himschott-Mitchell
# Truncating 'former_name' from 31 to 30 chars: MANDA KATHERINE DESJARLAIS KING
# Truncating 'former_name' from 31 to 30 chars: Mayerling Lourdia Choute-Joseph
# Truncating 'former_name' from 32 to 30 chars: MARGARET CHRISTINE ROBINSON HALL
# Truncating 'former_name' from 39 to 30 chars: CHRISTOPHER ALEXANDER MENDES-CHUMACEIRO
# Truncating 'former_name' from 32 to 30 chars: VILMA ILEANA RODRIGUEZ CABALLERO
# Truncating 'former_name' from 32 to 30 chars: Geraldine Stephine Reed Spangler
# Truncating 'former_name' from 32 to 30 chars: GABRIELA SUSANA THOMSEN MARTINEZ
# Truncating 'former_name' from 38 to 30 chars: EMILY JO ANGEL SPRING SUNSHINE FLEMING
# Truncating 'former_name' from 31 to 30 chars: Janet Holroyd And Janet Pearson
# Truncating 'former_name' from 31 to 30 chars: Melissa  Neyda Hernandez-Robles
# Truncating 'former_name' from 32 to 30 chars: Khalilah Uganda Coretta Williams
# Truncating 'former_name' from 33 to 30 chars: MARTA DESINET SAAVEDRA PORTALATIN
# Truncating 'former_name' from 31 to 30 chars: ALEXANDER ROBERT SILVIO CERCHIE
# Truncating 'former_name' from 31 to 30 chars: Femi Latifa Baraka Eva Sterling
# Truncating 'former_name' from 33 to 30 chars: YANAISY YADIRA HERNANDEZ CHIKITUS
# Truncating 'former_name' from 32 to 30 chars: Valencia Tequila Deann Truesdell
# Truncating 'former_name' from 31 to 30 chars: Takenia Varsarya Chetess Fuller
# Truncating 'former_name' from 33 to 30 chars: THERESA LEE VERPLANKE DE ARELLANO
# Truncating 'former_name' from 33 to 30 chars: CARLOS JULIO FERNANDES MARQUINHOS
# Truncating 'former_name' from 37 to 30 chars: COURTNEY ELEASE PATRICIA EUNICE JONES
# Truncating 'former_name' from 31 to 30 chars: RICHARD GREGORY VAN BOESSCHOTEN
# Truncating 'former_name' from 31 to 30 chars: DEVARSIOUS D'SHAAD KION MCCANTS
# Truncating 'former_name' from 32 to 30 chars: Benjamin Delahey Thomas-Larocquz
# Truncating 'former_name' from 33 to 30 chars: GEORGIA MARIE ROSENTHAL GOLDSTEIN
# Truncating 'former_name' from 36 to 30 chars: Samantha Margaret Fuschser-Mckinstry
# Truncating 'former_name' from 33 to 30 chars: Maritza Elizabeth Cedeno De Smith
# Truncating 'former_name' from 32 to 30 chars: GEORGE CHRISTOPHER TRIANTAFILLIS
# Truncating 'former_name' from 36 to 30 chars: CLAUDIO ANTONIO FERNANDES DE ALMEIDA
# Truncating 'former_name' from 33 to 30 chars: JELISSA KHANDI -JEAN MCLEOD-JAMES
# Truncating 'former_name' from 32 to 30 chars: JENNIFER GERALYN ALBRIGHT-EDBLAD
# Truncating 'former_name' from 31 to 30 chars: JOSE MIGUEL VAZQUEZ CIMADEVILLA
# Truncating 'former_name' from 35 to 30 chars: Kelly Roseann-Adrea Johnson-Hornsby
# Truncating 'former_name' from 40 to 30 chars: Harriette Del Carmen Fraticelli Gonzalez
# Truncating 'former_name' from 31 to 30 chars: George Michael Velazquez Arroyo
# Truncating 'former_name' from 31 to 30 chars: Kristin Nicole Crabtree Edwards
# Truncating 'former_name' from 31 to 30 chars: BRAIN HALL 16175 JOHN MORRIS RD
# Truncating 'former_name' from 35 to 30 chars: Alexander Lewis Sitegler Brockmeyer
# Truncating 'former_name' from 33 to 30 chars: Yamili Altagracia Rodriguez Reyes
# Truncating 'former_name' from 31 to 30 chars: PAULA YAZMIN LA PORTE FERNANDEZ
# Truncating 'former_name' from 34 to 30 chars: Isabella Mary Ambrosia Quiles Rosa
# Truncating 'former_name' from 32 to 30 chars: Dylan Michael Varanelli-Diccicco
# Truncating 'former_name' from 31 to 30 chars: Jose Alfonso Altamirano Palacio
# Truncating 'former_name' from 33 to 30 chars: Dennis Robet Buffington Vacchelli
# Truncating 'former_name' from 33 to 30 chars: Christine Susan Parker Szymanczyk
# Truncating 'former_name' from 31 to 30 chars: Casimira Vicenta Martinez Lopez
# Truncating 'former_name' from 33 to 30 chars: Albert Nicolas Rodriguez Carrasco
# Truncating 'former_name' from 32 to 30 chars: JORGE FELIX CONSUEGRA PIEDRAHITA
# Truncating 'former_name' from 31 to 30 chars: Calogero Gioseppo Vitaliano Iii
# Truncating 'former_name' from 31 to 30 chars: Molly Elizabeth Lee Satterfield
# Truncating 'former_name' from 31 to 30 chars: Francis Marion Modrezejewski Iv
# Truncating 'former_name' from 32 to 30 chars: Christine Ann Kraemer Rittberger
# Truncating 'former_name' from 31 to 30 chars: Dianne Steffany Vazquez Badillo
# Truncating 'former_name' from 34 to 30 chars: Natalie Cristina Acevedo Rodriguez
# Truncating 'former_name' from 32 to 30 chars: Maria Del Carmen Lopez Hernandez
# Truncating 'former_name' from 32 to 30 chars: AMY CHRISTINE HOSTIUCK-MARQUARDT
# Truncating 'former_name' from 31 to 30 chars: CAROLYN VIRGINIA WILLIAMS-SYKES
# Truncating 'former_name' from 35 to 30 chars: NANCY ELIZABETH MC ILRATH-GLANVILLE
# Truncating 'former_name' from 34 to 30 chars: MEGAN ELIZABETH SIPE (FORMER NAME)
# Truncating 'former_name' from 31 to 30 chars: MARCIE LYNETTE NICKELSON-TOBLER
# Truncating 'former_name' from 31 to 30 chars: ELIZABETH KENNELLY JUAREZ PEREZ
# Truncating 'former_name' from 31 to 30 chars: LINDSEY ELIZABETH FORD BOCHNIAK
# Truncating 'former_name' from 36 to 30 chars: Mary Brett Blankenship (Former Name)
# Truncating 'former_name' from 34 to 30 chars: WADE HAMPTON BERRY (WAS MISPELLED)
# Truncating 'former_name' from 32 to 30 chars: SENTOYRIA SADE SHANIECE SATCHELL
# Truncating 'former_name' from 32 to 30 chars: JACQUELINE ELIZABETH GAGNE ADAMS
# Truncating 'former_name' from 31 to 30 chars: REY ANTHONY JOHN GARDNER SAULOG
# Truncating 'former_name' from 31 to 30 chars: MARIA ANGENIS NICHOLE SCHROEDER
# Truncating 'former_name' from 33 to 30 chars: BRITTANY ALLISON CARTER ARMSTRONG
# Truncating 'former_name' from 31 to 30 chars: CHRISTINE T FISHERO-HERMSDORFER
# Truncating 'former_name' from 32 to 30 chars: JENNIFER NENETTA MORREALE MORGAN
# Truncating 'former_name' from 32 to 30 chars: CARLA DONIQUE THOMPSON-MCCORMICK
# Truncating 'former_name' from 31 to 30 chars: DESIREE JOY CONCEPCION MAGALONA
# Truncating 'former_name' from 31 to 30 chars: CAROLYN ELAINE JOHNSON TASCHNER
# Truncating 'former_name' from 31 to 30 chars: DEIDRA ANTONETTE JONES-JENNINGS
# Truncating 'former_name' from 33 to 30 chars: JENNIFER REGALADO DE JESUS ZIBART
# Truncating 'former_name' from 32 to 30 chars: LORRAINE DOROTHY DUBE-BULLERWELL
# Truncating 'former_name' from 32 to 30 chars: CARMEN LEILA DELGADO- ECHEVARRIA
# Truncating 'former_name' from 32 to 30 chars: BREANNE NYCOLE DELOSE REYES PINE
# Truncating 'former_name' from 35 to 30 chars: LILLI SHIREEN BAGHERI KOLAH JENKINS
# Truncating 'former_name' from 32 to 30 chars: SHENAN AMBER JOAN PATSY PHILLIPS
# Truncating 'former_name' from 40 to 30 chars: JONATHAN THOMAS WATTS 10212 WELLHOUSE CO
# Truncating 'former_name' from 31 to 30 chars: SANDY LAURENCIA BARBARA ETIENNE
# Truncating 'former_name' from 31 to 30 chars: BRIANNA NICOLE ALLISON MARSHALL
# Truncating 'former_name' from 31 to 30 chars: MELISSA LESHONE SHARPE-WILLIAMS
# Truncating 'former_name' from 31 to 30 chars: KENNIKA IVY ZSALAHNVIAUX TURNER
# Truncating 'former_name' from 34 to 30 chars: JULIANNA SCHWEIBINZ CARVALHO REGIS
# Truncating 'former_name' from 32 to 30 chars: PAMELA BRECHELLE STANBERY GIPSON
# Truncating 'former_name' from 32 to 30 chars: SIMONA ARETINA BRINSON-VANHOUSEN
# Truncating 'former_name' from 31 to 30 chars: THERESA MAUREEN VENTURA MUGAVIN
# Truncating 'former_name' from 31 to 30 chars: LESLIE MCCMURTREY ALISSANDRATOS
# Truncating 'former_name' from 31 to 30 chars: CHRISTINA SEAVER MCNALLY RAYNOR
# Truncating 'former_name' from 32 to 30 chars: GERRICA MARIE LAROCCA-MONTALBANO
# Truncating 'former_name' from 40 to 30 chars: MARY LEE STANFORD  (PLS MAKE CORRECTION)
# Truncating 'former_name' from 33 to 30 chars: VICTORIA ANNE ELIZABETH RIENECKER
# Truncating 'former_name' from 31 to 30 chars: KIMBERLY ESTHER RIVERA SANTIAGO
# Truncating 'former_name' from 40 to 30 chars: THINKS PREV CO WAS CLAY CO - ZIP UNKNOWN
# Truncating 'former_name' from 31 to 30 chars: ASHLEY NYCOLE GIOVANNA MARTUCCI
# Truncating 'former_name' from 31 to 30 chars: CATHERINE ELIZABETH MASTRACCHIO
# Truncating 'former_name' from 32 to 30 chars: MARIA ALEJANDRA GUTIERREZ HOLGUN
# Truncating 'former_name' from 31 to 30 chars: ALEXIANNA MARIEGRACIEMAE BENSON
# Truncating 'former_name' from 31 to 30 chars: KASSANDRA VAE DELLBRUEGGE-HURST
# Truncating 'former_name' from 33 to 30 chars: SHIRLEY CLAUDETTE MCGRAW ANDERSON
# Truncating 'former_name' from 31 to 30 chars: EDGAR ALNARDO HERNANDEZ ACEVEDO
# Truncating 'former_name' from 31 to 30 chars: KAHERINE THEONA BENDO HITCHINGS
# Truncating 'former_name' from 35 to 30 chars: CORRECTION OF PREVIOUS REGISTRATION
# Truncating 'former_name' from 31 to 30 chars: Elizabeth Pollard Manker Weimer
# Truncating 'former_name' from 32 to 30 chars: Eilizabeth April Dawn Stachowiak
# Truncating 'former_name' from 32 to 30 chars: JAMES DEWEY CHRISTOPHER WILLIAMS
# Truncating 'former_name' from 34 to 30 chars: Hiram Salvatore De Jesus Archimede
# Truncating 'former_name' from 31 to 30 chars: William Frederick Strickengloss
# Truncating 'former_name' from 32 to 30 chars: Nyamekyer Elvida Scarlett-Seaser
# Truncating 'former_name' from 33 to 30 chars: Jacqueline Maldonado Lozada Ayala
# Truncating 'former_name' from 32 to 30 chars: TABITH GEORGETTE TEACHMAN KRAMER
# Truncating 'former_name' from 31 to 30 chars: Christy Michelle Deshazo Bertka
# Truncating 'former_name' from 31 to 30 chars: ESMERALDA DARLEN MOLINA BARAJAS
# Truncating 'former_name' from 34 to 30 chars: TATJANA STEPHANIE BARRETO MADRIGAL
# Truncating 'former_name' from 33 to 30 chars: CHRISTOPHER ORLANDO TORRES TORRES
# Truncating 'former_name' from 34 to 30 chars: Jessica Julie Christine Bennefield
# Truncating 'former_name' from 32 to 30 chars: Yolanda Dominguez Perez Castillo
# Truncating 'former_name' from 32 to 30 chars: Patricia Marlene Griffin Bradley
# Truncating 'former_name' from 31 to 30 chars: HAROLD OSCAR ESTRADAS RODRIGUEZ
# Truncating 'former_name' from 32 to 30 chars: ZONTRAVIA NAKOTAS MYSTIQUE BROWN
# Truncating 'former_name' from 31 to 30 chars: Valentine Francis Rymanowski Jr
# Truncating 'former_name' from 31 to 30 chars: Michele Margaret Veldran-Osorto
# Truncating 'former_name' from 33 to 30 chars: Carmen Leticia Morales Villanueva
# Truncating 'former_name' from 32 to 30 chars: Luciano Miguel Martinez Gonzalez
# Truncating 'former_name' from 33 to 30 chars: VANESSA JEAN VAN DER MEID-JACKSON
# Truncating 'former_name' from 31 to 30 chars: ABRAXIS JAMIE ELIZABETH PRESTON
# Truncating 'former_name' from 34 to 30 chars: AMELIA JOSEPHINE GALLO ARZOUMANIAN
# Truncating 'former_name' from 31 to 30 chars: ILEAN JACQUIELINE MELTON-ZELAYA
# Truncating 'former_name' from 31 to 30 chars: RAQUEL IVETTE CORDOVES MARCHESE
# Truncating 'former_name' from 31 to 30 chars: GEORGIA HENDRICA DE STOPPELAIRE
# Truncating 'former_name' from 31 to 30 chars: DARSHANA N PATEL-RAMHARACKSINGH
# Truncating 'former_name' from 40 to 30 chars: Lesley-Ann Kuulei Kalehuammakanoe Theaux
# Truncating 'former_name' from 33 to 30 chars: ALEXANDER,NEFERTITI DAMALI RETINA
# Truncating 'former_name' from 31 to 30 chars: JENNIFER ADAIR KAESTNER WALTERS
# Truncating 'former_name' from 31 to 30 chars: DEIRDRE ANN GONSALVES RODRIGUEZ
# Truncating 'former_name' from 32 to 30 chars: JOHANNA ALEXANDRA SUAREZ SANCHEZ
# Truncating 'former_name' from 35 to 30 chars: MARIE MARCELLE LUCIENNE SAINT-FLEUR
# Truncating 'former_name' from 33 to 30 chars: JACQUELINE ESTANDIAN DE LOS REYES
# Truncating 'former_name' from 31 to 30 chars: SHAWANA COZELLA CRAYTON REDDICK
# Truncating 'former_name' from 32 to 30 chars: CARISSA CHRISTIANNA DELLA PIETRA
# Truncating 'former_name' from 31 to 30 chars: HEATHER RENEE BELLUCCI SANTILLO
# Truncating 'former_name' from 32 to 30 chars: PHILOMENA SUSAN MARINACCIO-ECKEL
# Truncating 'former_name' from 33 to 30 chars: CHRISTINA MARIE CHIARAMIDA HARDIN
# Truncating 'former_name' from 34 to 30 chars: SAMILLIA NICOLE NEVERS-WHITTINGHAM
# Truncating 'former_name' from 35 to 30 chars: PASTORIZA CRESPO, VICENTE FRANCISCO
# Truncating 'former_name' from 31 to 30 chars: JOSE ARMANDO DELATORRE VALENTIN
# Truncating 'former_name' from 36 to 30 chars: STEFFANIE DANIELLE CACCIATORE-DEVLIC
# Truncating 'former_name' from 31 to 30 chars: NICHOLAS ALFREDO MASTROIANNI II
# Truncating 'former_name' from 33 to 30 chars: BLUNZELL STANLEY BRIDGES AUGUSTIN
# Truncating 'former_name' from 31 to 30 chars: MEREDITH ELAINE MINUS ETHEREDGE
# Truncating 'former_name' from 32 to 30 chars: THERESA MARY HALABUTDA-ALEXANDER
# Truncating 'former_name' from 33 to 30 chars: MARGARET ELIZABETH GEDDES RICHMAN
# Truncating 'former_name' from 32 to 30 chars: MAYA JANELLE BRAILFORD VON HALLE
# Truncating 'former_name' from 33 to 30 chars: LATONYA ROCHELLE DANIELS-HOLLOWAY
# Truncating 'former_name' from 32 to 30 chars: AVIS BERNADETE SPRADLEY-STEPHENS
# Truncating 'former_name' from 32 to 30 chars: VIRGINIA SUSAN EUTENEUER-CARDOSO
# Truncating 'former_name' from 32 to 30 chars: Tara Lashandra Whigham-Parchment
# Truncating 'former_name' from 31 to 30 chars: BRANDY KALEIPUANANI CABAN-MUNIZ
# Truncating 'former_name' from 34 to 30 chars: JENNIFER FLORENCE GARUCKASGARDELLA
# Truncating 'former_name' from 31 to 30 chars: MICHELLE LYNN LONGARZO-CASTILLO
# Truncating 'former_name' from 36 to 30 chars: NOREEN CHRISTINE BHOORASINGH - BROWN
# Truncating 'former_name' from 33 to 30 chars: ANDREA MICHELLE JOHNSON-MARSEILLE
# Truncating 'former_name' from 31 to 30 chars: DAWSIB-LAVARADO TERIELL LASHAWN
# Truncating 'former_name' from 36 to 30 chars: DUNCAN-DIEUJUSTE,KRISTINA ANNA-MARIE
# Truncating 'former_name' from 33 to 30 chars: JACQUELINE ALEXANDRIA KARANTZALIE
# Truncating 'former_name' from 36 to 30 chars: BARBARA DE LA CARIDAD ALFARO-RUFFINO
# Truncating 'former_name' from 34 to 30 chars: CHRISTINE CATHERINE HANSLER LYKINS
# Truncating 'former_name' from 31 to 30 chars: HEATHER MICHELLE SOLON DE MELLO
# Truncating 'former_name' from 34 to 30 chars: VIRGEN MILAGROS HERNANDEZ FIGUEROA
# Truncating 'former_name' from 31 to 30 chars: JUDITH DAWN STOJANOVICH STEVENS
# Truncating 'mailing_zipcode' from 15 to 12 chars: EDO NVA ESPARTA
# Truncating 'former_name' from 31 to 30 chars: MARIE JESULA JN LOUIS MILLIANCE
# Truncating 'former_name' from 32 to 30 chars: INEZ BERYL MARIE LAYNE FLEISCHER
# Truncating 'former_name' from 33 to 30 chars: SADRINA SANTARIA HABERSHAM JUMPER
# Truncating 'former_name' from 33 to 30 chars: CHRISTOPHER MAHENDRAN SAVERIMUTTU
# Truncating 'former_name' from 33 to 30 chars: MARGARITA LYNN SERVITO MC MURRAIN
# Truncating 'former_name' from 32 to 30 chars: CAMILLA LIZ IBRAGIMOVA MISKOVICH
# Truncating 'former_name' from 32 to 30 chars: MARIE CASSANDRE LOUITUS MATHURIN
# Truncating 'former_name' from 33 to 30 chars: FRANCES NYANIBA KYEREMATEN-AFRANI
# Truncating 'former_name' from 32 to 30 chars: SIMONEY JORDANA ROACHE WILKINSON
# Truncating 'former_name' from 31 to 30 chars: OLGA CRISTINE LUCERO DE DIPAULI
# Truncating 'former_name' from 31 to 30 chars: DEIA MARIE PEARL FRANCIS WILKES
# Truncating 'former_name' from 33 to 30 chars: BEAUTAH AMANDA FERGUSON GRANDISON
# Truncating 'former_name' from 32 to 30 chars: RITA  MARINA SOCORRO CASTELLANOS
# Truncating 'former_name' from 35 to 30 chars: ANITA CHRISTINA VILLAFUERTE DE VEGA
# Truncating 'former_name' from 31 to 30 chars: GAYNELL YVETTE JACKSON-HARRISON
# Truncating 'former_name' from 32 to 30 chars: SARA ELIZABETH TAMAR SWITKOWSKII
# Truncating 'former_name' from 32 to 30 chars: JEANNE ROLANDE SAUVAL BELLEGARDE
# Truncating 'former_name' from 33 to 30 chars: ANNE KATHRYN FENNIMORE-TOROPAINEN
# Truncating 'former_name' from 31 to 30 chars: GERMAN ESTEBAN MARTINEZ SEGEBRE
# Truncating 'former_name' from 34 to 30 chars: EMMANUELLA CHRISTINE JEAN PHILIPPE
# Truncating 'former_name' from 34 to 30 chars: OLIVAREGUERRIRE, CHRISTIAN ALDONSO
# Truncating 'former_name' from 37 to 30 chars: EDITH MARIE ELIZABETH FRANCO MONSALVE
# Truncating 'former_name' from 31 to 30 chars: RICKY ALEXANDER FIALLOS-BENNETT
# Truncating 'former_name' from 32 to 30 chars: SHAYNA LEIGHANN GRUMBLEY-CASAREZ
# Truncating 'former_name' from 31 to 30 chars: BETTY ELIZABETH JEAN NAGY NIXON
# Truncating 'former_name' from 33 to 30 chars: BRIDGET ELIZABETH  SULLIVAN PANSE
# Truncating 'former_name' from 36 to 30 chars: GLADYS YOUSEPINA FIERAMOSCA DE TAPIA
# Truncating 'former_name' from 36 to 30 chars: Roshanara Patricia Feliciano-Bonilla
# Truncating 'former_name' from 31 to 30 chars: KATARINE KAROLINE LICANTE DUTRA
# Truncating 'former_name' from 32 to 30 chars: CLUADIA PATRICIA CADAVID ALMEIDA
# Truncating 'former_name' from 35 to 30 chars: LAURIE ANNE GRAY--NAME CHANGE ERROR
# Truncating 'former_name' from 35 to 30 chars: DAPHNE MINNIE-RUTH COHEN- BERKOWITZ
# Truncating 'former_name' from 31 to 30 chars: MELANIE  JAYNE ROBERTSON BRYANT
# Truncating 'former_name' from 32 to 30 chars: THEODOROS KONSTANTINOS GRIGORIOU
# Truncating 'former_name' from 33 to 30 chars: JAIANNE CLAUDINE CASACLANG AQUINO
# Truncating 'former_name' from 33 to 30 chars: CHARMAINE ANN MAIRE HYLTON MORGON
# Truncating 'former_name' from 40 to 30 chars: STANIEL TULIP CHIKWELU AGHAJI-ENWEREMADU
# Truncating 'former_name' from 34 to 30 chars: JAHKERIA DENETTA MCLEMORE-STEPHENS
# Truncating 'former_name' from 33 to 30 chars: KATHERINA MICHELLE PEREZ SANTIAGO
# Truncating 'former_name' from 33 to 30 chars: Krista Elizabeth Kuebler (Janaes)
# Truncating 'former_name' from 31 to 30 chars: TRICIA LISE CHATTERTON-GOLDRICK
# Truncating 'former_name' from 32 to 30 chars: JESUS ALBERTO PEREZ CH MC CARTHY
# Truncating 'former_name' from 36 to 30 chars: CARINA CHRISTINE COVERT-SCHWARZHAUPT
# Truncating 'former_name' from 32 to 30 chars: Sylvia Cristina Thomson Riquezes
# Truncating 'former_name' from 37 to 30 chars: MARIQUITA ANASTACIA BARTOLOME-SANCHEZ
# Truncating 'former_name' from 33 to 30 chars: ENERSTO RADHAMES MONTESINO VARGAS
# Truncating 'former_name' from 32 to 30 chars: AMANDA ELIZABETH POBIAK-SPEILLER
# Truncating 'former_name' from 31 to 30 chars: CHLOE CHRISTIANE SUZANNE MUXART
# Truncating 'former_name' from 33 to 30 chars: STRZELCZYK AGUSTIN, ANNA STEFANIA
# Truncating 'former_name' from 32 to 30 chars: SILBRINA ALEXANDRA ALVINA PORTER
# Truncating 'former_name' from 31 to 30 chars: ISAIAH WILLIAMS ALEXANDER HOBBS
# Truncating 'former_name' from 32 to 30 chars: MARIE LENISE DORJEAN SAINT-FLEUR
# Truncating 'former_name' from 34 to 30 chars: DUSTIN NATHANIEL MOORE GERASIMCHIK
# Truncating 'mailing_zipcode' from 15 to 12 chars: EDO NVA ESPARTA
# Truncating 'former_name' from 32 to 30 chars: DANIEL ALEXANDER ROLON RODRIGUEZ
# Truncating 'former_name' from 31 to 30 chars: MARCIA NICOLENE MCINTOSH WITTER
# Truncating 'former_name' from 36 to 30 chars: Catherine Andrea-Elvira Mavrogeorgis
# Truncating 'former_name' from 33 to 30 chars: TANEISHA TRESHANA SENIOR MARSHALL
# Truncating 'former_name' from 34 to 30 chars: Michelle Iriss Louise Rivera-Olson
# Truncating 'former_name' from 32 to 30 chars: VERONIQUE PATRICIA VABNER-POZNER
# Truncating 'former_name' from 32 to 30 chars: ELIZABETH CHERIE MEENTS ERICKSON
# Truncating 'former_name' from 34 to 30 chars: MARIA DEL CARMEN GONZALEZ CASTILLO
# Truncating 'former_name' from 33 to 30 chars: CAMPITELI, MARIETE GARCIA JOAQUIM
# Truncating 'former_name' from 31 to 30 chars: MARIE MARCELLE FRANCE VIGNEAULT
# Truncating 'former_name' from 35 to 30 chars: JACQUELINE MERCEDES MUNOZ RODRIGUEZ
# Truncating 'former_name' from 31 to 30 chars: KIMBERLY LYNN MILLER-ASADOORIAN
# Truncating 'former_name' from 35 to 30 chars: ZA'KIRIA LA'CHUNDRA TENESHIA O'NEAL
# Truncating 'former_name' from 31 to 30 chars: GABRIELLA ANDRADE SAMPAIO COLON
# Truncating 'former_name' from 31 to 30 chars: DENISE MICHELLE PARSHALL SLUMAN
# Truncating 'former_name' from 32 to 30 chars: JANET MARGARITA CASTILLO MORALES
# Truncating 'former_name' from 33 to 30 chars: ALESSANDRO AZEVEDO LEMBI DE FARIA
# Truncating 'former_name' from 31 to 30 chars: LOURDES IVETTE CANCEL MALDONADO
# Truncating 'former_name' from 31 to 30 chars: JENNIFER LYNN RODRIGUEZ CHICWAK
# Truncating 'former_name' from 34 to 30 chars: PIERETTE DEL ROSARIO BURGOS FERRER
# Truncating 'former_name' from 36 to 30 chars: MAYYADAH YAHYA ABDULRASOOL AL-DAHAWI
# Truncating 'former_name' from 31 to 30 chars: CHRISTOPHER LEE LINSINBIGLER II
# Truncating 'former_name' from 31 to 30 chars: VICTOR MANUEL FONTANEZ CUADRADO
# Truncating 'former_name' from 33 to 30 chars: FRANKLIN PATRICIO MOSCOSO MOSCOSO
# Truncating 'former_name' from 31 to 30 chars: HECTOR ANDRES IRIZARRY OSTOLAZA
# Truncating 'former_name' from 32 to 30 chars: NORAH MICHELLE RODRIQUEZ BULGALA
# Truncating 'former_name' from 37 to 30 chars: YOLANDA ALTAGARCIA DE JESUS RODRIGUEZ
# Truncating 'former_name' from 31 to 30 chars: MIRIAN VALENTIAN BARRERO MENDEZ
# Truncating 'former_name' from 35 to 30 chars: FERNANDO HOSSEIN ALVAREZ SHAHBAZNIA
# Truncating 'former_name' from 31 to 30 chars: NINOSKA SIVONEY GONZALEZ VARGAS
# Truncating 'former_name' from 33 to 30 chars: MACHEN VERONICA QUINN CHRISTENSON
# Truncating 'former_name' from 32 to 30 chars: ABIGAIL REBECCA LEONORA SHERIDAN
# Truncating 'former_name' from 37 to 30 chars: SILVA ROSEA DE LA CRUZ DIAZ DE FORERO
# Truncating 'former_name' from 40 to 30 chars: MARJORIE AFERGAN     CORR STATE OF BIRTH
# Truncating 'former_name' from 32 to 30 chars: LARISHA DIONNEDOMINIQUE CARSWELL
# Truncating 'former_name' from 31 to 30 chars: SRINIVAS SAMBA SIVA SHAST YELLI
# Truncating 'former_name' from 34 to 30 chars: HILSA R FERNANDEZ PADILLA DE PEREZ
# Truncating 'former_name' from 32 to 30 chars: Michelle Sampaio Tishler Meadows
# Truncating 'former_name' from 40 to 30 chars: Stephanie Elizabeth De Falco-Varnavelias
# Truncating 'former_name' from 36 to 30 chars: Donald Robert Lachappelle-Wallace Ii
# Truncating 'former_name' from 32 to 30 chars: QUERNECIA LATRICE CALDWELL MAYES
# Truncating 'former_name' from 36 to 30 chars: Christine Andrienne Helene Carnathan
# Truncating 'former_name' from 31 to 30 chars: Deborah Susan Beauparlant-Brant
# Truncating 'former_name' from 33 to 30 chars: KENDRA DANIELLE GUILFORD-STEPHENS
# Truncating 'former_name' from 32 to 30 chars: Jessica Nicole Antonio Giambrone
# Truncating 'former_name' from 32 to 30 chars: JOSE ANTONIO DEL VALLE RODRIQUEZ
# Truncating 'former_name' from 34 to 30 chars: Michelle Marie Rodriguez Velazquez
# Truncating 'former_name' from 33 to 30 chars: Kristin Nicole Westhoven Heminger
# Truncating 'former_name' from 31 to 30 chars: Beth Charney Silverman Peterson
# Truncating 'former_name' from 34 to 30 chars: Margareth Catherine Stewart Pedlow
# Truncating 'former_name' from 31 to 30 chars: Kandi Denise Liz Wilson Jenkins
# Truncating 'former_name' from 31 to 30 chars: GABRIEL MANUEL GONZALEZ RAMIREZ
# Truncating 'former_name' from 31 to 30 chars: Johnathon Earl Cherry-Magnussen
# Truncating 'former_name' from 34 to 30 chars: Marianne Harley Thurston -Williams
# Truncating 'former_name' from 31 to 30 chars: AUDREY LORRAINE WOFFORD-SAMUELS
# Truncating 'former_name' from 31 to 30 chars: Merrell Elizabeth Lightner Shye
# Truncating 'former_name' from 33 to 30 chars: JULIA CHRISTINE LEMOUREUX-ARTHURS
# Truncating 'former_name' from 37 to 30 chars: Summer Linnette Fredricka Lee Huggins
# Truncating 'former_name' from 32 to 30 chars: Brooke Elizabeth Buenzli-Paholik
# Truncating 'former_name' from 34 to 30 chars: Myrna Lorraine Galligano-Kozlowski
# Truncating 'former_name' from 32 to 30 chars: Michele Marie Montgomery-Bobertz
# Truncating 'former_name' from 32 to 30 chars: Stephanie Jean Salvatore Moffitt
# Truncating 'former_name' from 36 to 30 chars: TALOTHA ROSE MARIE HARTLINE-PARADISE
# Truncating 'former_name' from 40 to 30 chars: Julie Yeo (Customer States Previous Name
# Truncating 'former_name' from 34 to 30 chars: Mondavian De Grandpre Richemontier
# Truncating 'former_name' from 32 to 30 chars: Tamela Michelle Summers-Intrieri
# Truncating 'former_name' from 34 to 30 chars: Hermilyn Clementina Phillips-Juvan
# Truncating 'former_name' from 31 to 30 chars: AHMANEE WAKEELAH COLLINS-BANDOO
# Truncating 'former_name' from 33 to 30 chars: Elanor Louise Whittington Clenney
# Truncating 'former_name' from 34 to 30 chars: SIXTA DEL ROSARIO CARMONA GONZALEZ
# Truncating 'former_name' from 31 to 30 chars: Cynthia Annetta Collins Edwards
# Truncating 'former_name' from 31 to 30 chars: Rebecca Mary Elizabeth Glaubitz
# Truncating 'former_name' from 31 to 30 chars: ANGEL ANTONIO LOPEZ DE VICTORIA
# Truncating 'former_name' from 31 to 30 chars: Andrea Elizabeth Vialva Collins
# Truncating 'former_name' from 35 to 30 chars: Taralynn Lorraine Bernice Lowenthal
# Truncating 'former_name' from 32 to 30 chars: TIFFNY CHRITINNE HERNANDEZ RAMOS
# Truncating 'former_name' from 32 to 30 chars: Kourtney Denise Mcelroy Or Green
# Truncating 'former_name' from 32 to 30 chars: VICTORIA SAMANTHA PAWNEE SIRMONS
# Truncating 'former_name' from 33 to 30 chars: Taylor Kathleen Stallings Pinnick
# Truncating 'former_name' from 31 to 30 chars: Charles Ancrew Dismas Mcphilamy
# Truncating 'former_name' from 32 to 30 chars: LINDA MICHELLE WILLIAMS MCENTYRE
# Truncating 'former_name' from 39 to 30 chars: DANIELL MARIE BRADSHAW (MAYBE CAMPBELL)
# Truncating 'former_name' from 31 to 30 chars: Cortney Gina Corbin-Capodiferro
# Truncating 'former_name' from 31 to 30 chars: LAWRENCE PHILLIP SCHLERNITZAUER
# Truncating 'former_name' from 33 to 30 chars: SASHA AMANDA ANNALEE CORBIN-HODGE
# Truncating 'former_name' from 31 to 30 chars: Mariane Michelle Colon Zambrana
# Truncating 'former_name' from 31 to 30 chars: Madeline Johanna Hernandez Soto
# Truncating 'former_name' from 31 to 30 chars: Alison Michele Van Zyll De Jong
# Truncating 'former_name' from 32 to 30 chars: Brooke Christine Ashley Hedelund
# Truncating 'former_name' from 33 to 30 chars: STEPHANIE MARIE MARTINEZ COSTELLO
# Truncating 'former_name' from 31 to 30 chars: AMANDA ROSE WETHERILL LEYMASTER
# Truncating 'former_name' from 31 to 30 chars: Datanis Crystal Rodriguez Urena
# Truncating 'former_name' from 34 to 30 chars: Kari Elizabeth Rodriguez - Santana
# Truncating 'former_name' from 31 to 30 chars: Alexandra Whitney Ricke-Vergara
# Truncating 'former_name' from 31 to 30 chars: Channing Alexis Finger Gonzalez
# Truncating 'former_name' from 31 to 30 chars: Jennifer Ashley Stephens Sheard
# Truncating 'former_name' from 31 to 30 chars: Martika Michele Thomas-Matthews
# Truncating 'former_name' from 32 to 30 chars: Siuly Aslin Echevarria Fernandez
# Truncating 'former_name' from 32 to 30 chars: KAHMARAE MONAE RUTH EATIN DUNCAN
# Truncating 'former_name' from 31 to 30 chars: Jacqueline Ann Vazquez Melendez
# Truncating 'former_name' from 31 to 30 chars: Claudia Aracely Adams-Vaquedano
# Truncating 'former_name' from 33 to 30 chars: Jacqueline Lorett Power Rochowiak
# Truncating 'former_name' from 31 to 30 chars: Samantha Marie Selig-Silberzahn
# Truncating 'former_name' from 31 to 30 chars: SHARDINAI KEYARA QUANIESHA DEAN
# Truncating 'former_name' from 31 to 30 chars: FRANCIS YAMIL SUSTACHE DELCAMPO
# Truncating 'former_name' from 31 to 30 chars: Denise Carol Handy Bailey Houle
# Truncating 'former_name' from 31 to 30 chars: Kristine Leslie Traver Hathaway
# Truncating 'former_name' from 31 to 30 chars: ROSALIE EUGENIE NORMAN-MC NANEY
# Truncating 'former_name' from 33 to 30 chars: Peaches  Chakera Douglas-Pluviose
# Truncating 'former_name' from 31 to 30 chars: Deborah Marie Sutherland Gordon
# Truncating 'former_name' from 31 to 30 chars: ELIZABETH SHARLEEN TORRES RAMOS
# Truncating 'former_name' from 32 to 30 chars: Katherine Willa H Oterman Kramer
# Truncating 'former_name' from 33 to 30 chars: DENISE FRANCES TAVERNIER ROSSETTI
# Truncating 'former_name' from 33 to 30 chars: DANIEL GIOVANNI RAFFAELLI HERMOSO
# Truncating 'former_name' from 36 to 30 chars: Catherine Ashley Funderburke-Swingle
# Truncating 'former_name' from 33 to 30 chars: Shannon Angelita Makanani Averett
# Truncating 'former_name' from 31 to 30 chars: Zenon Guillermo Panchana-Chavez
# Truncating 'former_name' from 31 to 30 chars: Katherine Elisabeth Riley Darby
# Truncating 'former_name' from 33 to 30 chars: Marcus Jeorritha Darnel Jefferson
# Truncating 'former_name' from 31 to 30 chars: Jasmine Michelle Daniel-Persaud
# Truncating 'former_name' from 33 to 30 chars: RHIO EDUARDO DE LOS SANTOS RENDON
# Truncating 'former_name' from 34 to 30 chars: Melissa Nichole Hoku Maka'Lii Boyk
# Truncating 'former_name' from 37 to 30 chars: Maydaliz Del Rosario Rivera Velazquez
# Truncating 'former_name' from 31 to 30 chars: Allison Renee Meckenstock Junco
# Truncating 'former_name' from 31 to 30 chars: Carlos Manuel Pagan Clemente Jr
# Truncating 'former_name' from 34 to 30 chars: Mary Ellen Julie Mc Cormack-Mervis
# Truncating 'former_name' from 31 to 30 chars: Sonny Steven Calderon Rodriguez
# Truncating 'former_name' from 40 to 30 chars: JESSICA PERISSE MOREIRA MARTINS DE MACED
# Truncating 'former_name' from 37 to 30 chars: Not Moved Post Office Changes Mailing
# Truncating 'former_name' from 31 to 30 chars: Donna Marie Ragauckas Musselman
# Truncating 'former_name' from 32 to 30 chars: FRANCINE EVERNE DANIELS-ANDERSON
# Truncating 'former_name' from 33 to 30 chars: Arthronia Niseah Holsley-Robinson
# Truncating 'former_name' from 34 to 30 chars: Rashawnda Latoria Young-Washington
# Truncating 'former_name' from 40 to 30 chars: Customer Thinks This Old One/Race Change
# Truncating 'former_name' from 31 to 30 chars: Rebecca Shinholser Mickholtzick
# Truncating 'former_name' from 33 to 30 chars: Marbella Cristina Sifontes Ospino
# Truncating 'former_name' from 31 to 30 chars: Christopher Combra Marque White
# Truncating 'former_name' from 34 to 30 chars: TWANISHA CHANTELLE GORDON- PRESLEY
# Truncating 'former_name' from 32 to 30 chars: Crystaldominiqu Rochelle Coleman
# Truncating 'former_name' from 31 to 30 chars: James Michaeldominick Hanningan
# Truncating 'former_name' from 31 to 30 chars: Katherine Denise Cerozier-Theis
# Truncating 'former_name' from 33 to 30 chars: HEIDI CHRISTINA DE MELO AGOSTINHO
# Truncating 'former_name' from 31 to 30 chars: Leslie Elizabeth Holland Robert
# Truncating 'former_name' from 32 to 30 chars: Nancy Elizabeth Rosario-Sammuels
# Truncating 'former_name' from 36 to 30 chars: Michele Antoinette Richardson-Lozano
# Truncating 'former_name' from 49 to 30 chars: Sandrie K. Dieujuste (Misprint On Middle Initial)
# Truncating 'former_name' from 34 to 30 chars: HUMBERTO JOHN ANTHONY DIAZ DE ARCE
# Truncating 'former_name' from 31 to 30 chars: Daniela Andrea Montoya-Fontalvo
# Truncating 'former_name' from 33 to 30 chars: LAURA MARIAN KOZMINSKI VANDERHART
# Truncating 'former_name' from 32 to 30 chars: Janavi Amarilys Santana Laureano
# Truncating 'former_name' from 32 to 30 chars: Robert Michael Mollet Bloomquist
# Truncating 'former_name' from 36 to 30 chars: CUSTOMER THINKS THIS IS LAST ADDRESS
# Truncating 'former_name' from 31 to 30 chars: LAWRENCE WOODBURY RASMUSSEN III
# Truncating 'former_name' from 31 to 30 chars: CLODOALDO ALESSANDRO CAVALCANTE
# Truncating 'former_name' from 32 to 30 chars: Maria Theressa Campomanes Genito
# Truncating 'former_name' from 31 to 30 chars: Wanda Melanie Martinez Narvarro
# Truncating 'former_name' from 35 to 30 chars: Samantha Sylvia Louise Dunkelberger
# Truncating 'former_name' from 32 to 30 chars: Lauren Emily Devance Eisenschenk
# Truncating 'former_name' from 32 to 30 chars: Toria Caitlin Mclaghlin Martinez
# Truncating 'former_name' from 32 to 30 chars: Antoinette Shemwell-St. Matthews
# Truncating 'former_name' from 32 to 30 chars: Cecelia Collette Carpenter-Hicks
# Truncating 'former_name' from 31 to 30 chars: Benjamin Harrison Mathewson Iii
# Truncating 'former_name' from 35 to 30 chars: MUJAAHIDA MALI RASHEEDAH BINT DUFFY
# Truncating 'former_name' from 33 to 30 chars: BELINDA YASMEEN MOUGHAL CHEVALIER
# Truncating 'former_name' from 34 to 30 chars: ALEXANDRA MARIE GEORGIOU DJIOVANIS
# Truncating 'former_name' from 32 to 30 chars: ALICE DARLENE HUNTSINGER HEDRICK
# Truncating 'former_name' from 31 to 30 chars: NORMA FAYE CRABB - NORMA TOLSON
# Truncating 'former_name' from 31 to 30 chars: SHERRY LEE LOUISE PETRIN-RUCCIA
# Truncating 'former_name' from 32 to 30 chars: DOROTHY FRANCES VAN TASSEL RAGER
# Truncating 'former_name' from 33 to 30 chars: CC MICHAEL-DI AUDRE ALEXIS CIREZZ
# Truncating 'former_name' from 31 to 30 chars: KATHLEEN PATRICIA DALLAS-MATURI
# Truncating 'former_name' from 31 to 30 chars: SUSAN ELAINE ALTIZER-SCHREIFELS
# Truncating 'former_name' from 32 to 30 chars: Ashley Nichole Sexton Yarborough
# Truncating 'former_name' from 35 to 30 chars: Katherine Victoria Ripley-Slaughter
# Truncating 'former_name' from 31 to 30 chars: Christina Sophia Marie Whitwood
# Truncating 'former_name' from 32 to 30 chars: PATRICIA DIANE REEVES RICHARDSON
# Truncating 'former_name' from 31 to 30 chars: PARAGO NICOLA FE BOTHE-WILLIAMS
# Truncating 'former_name' from 33 to 30 chars: ELENA  KATHERINE KRUL-JAC K SMITH
# Truncating 'former_name' from 32 to 30 chars: EDDIE ESQUILIN ESQUILIN MARTINEZ
# Truncating 'former_name' from 31 to 30 chars: FRANCES LINDSEY MILLETTE BRYANT
# Truncating 'former_name' from 31 to 30 chars: ALECIA CLAIRE CARPENTER GARDNER
# Truncating 'former_name' from 34 to 30 chars: ALEXANDER LAURENCE JOHN BLOOMQUIST
# Truncating 'former_name' from 34 to 30 chars: THURMAN KENNETH PEARCE MINCHEW III
# Truncating 'former_name' from 33 to 30 chars: APOSTOLIS MOYRELATOS  (INCORRECT)
# Truncating 'former_name' from 31 to 30 chars: ASHLEY BLAIR GUMATAOTAO FEJARAN
# Truncating 'former_name' from 33 to 30 chars: AMARYLLIS DE LA CARIDAD RODRIGUEZ
# Truncating 'former_name' from 35 to 30 chars: STEPHANIE JOMALICE CAAMANO MONTALVO
# Truncating 'former_name' from 36 to 30 chars: EDUARDO ALEXANDRE MATIAS DE CARVALHO
# Truncating 'former_name' from 31 to 30 chars: KRISTIN MARIE KULTGEN DOMINGUEZ
# Truncating 'former_name' from 31 to 30 chars: ARNOLD VLADINIROVICH PLYUSHCHEV
# Truncating 'former_name' from 31 to 30 chars: TIFFANY ANN DOTTERMAN-MOLLICONE
# Truncating 'former_name' from 31 to 30 chars: LISA CHURCH VASSER (MISSPELLED)
# Truncating 'former_name' from 39 to 30 chars: **ST JOHNS CO BEFORE - NOT SURE ADDRESS
# Truncating 'former_name' from 33 to 30 chars: KITARA LASHAWN LITTLES WASHINGTON
# Truncating 'former_name' from 32 to 30 chars: Jacqueline Lee Nichole Johansson
# Truncating 'former_name' from 33 to 30 chars: Sandra Altagracia Lavandier Lopez
# Truncating 'former_name' from 33 to 30 chars: Quanneise Naterra Jenkins-Findlay
# Truncating 'former_name' from 31 to 30 chars: Christiana Shevellanie Mckenzie
# Truncating 'former_name' from 31 to 30 chars: WENDELL ANTHONY FRAZIER-COLLAZO
# Truncating 'former_name' from 37 to 30 chars: Sheryl Redlinger Murphy (Former Name)
# Truncating 'former_name' from 32 to 30 chars: Cynthia Dawn Schufeldt-Glanville
# Truncating 'former_name' from 33 to 30 chars: Christine Elaine Waterford Furlow
# Truncating 'former_name' from 32 to 30 chars: Lisa Kay Schreiber (Former Name)
# Truncating 'former_name' from 32 to 30 chars: Rachel Lauren Witt (Former Name)
# Truncating 'former_name' from 37 to 30 chars: Terri Edenfield Hampton (Former Name)
# Truncating 'former_name' from 35 to 30 chars: Middle Name Misspelled On Prev Card
# Truncating 'former_name' from 32 to 30 chars: Darlene Michelle Robinson Vinson
# Truncating 'former_name' from 37 to 30 chars: Demetrea Furlow Griffin (Former Name)
# Truncating 'former_name' from 38 to 30 chars: Kristeen Nicole Gillooly (Former Name)
# Truncating 'former_name' from 37 to 30 chars: Everlena Louise Wheaton (Former Name)
# Truncating 'former_name' from 34 to 30 chars: Sharon Alane Mcclurg (Former Name)
# Truncating 'former_name' from 35 to 30 chars: Christina Grace Delicano Villanueva
# Truncating 'former_name' from 31 to 30 chars: Kelly Christine Barett Williams
# Truncating 'former_name' from 34 to 30 chars: Shannon Kathleen Andrews-Ledgister
# Truncating 'former_name' from 34 to 30 chars: Tamatha Ellen Thomas (Former Name)
# Truncating 'former_name' from 34 to 30 chars: LAKEITHA MARVETTE COPELAND-WEBSTER
# Truncating 'former_name' from 32 to 30 chars: Patrice Lynette Mcgriff Mcgregor
# Truncating 'former_name' from 33 to 30 chars: Delisha Alexander Mcdaniel-Martin
# Truncating 'former_name' from 33 to 30 chars: Carlos Ignacio Santiago Hernandez
# Truncating 'former_name' from 34 to 30 chars: Kelly Jean Lancaster (Former Name)
# Truncating 'former_name' from 31 to 30 chars: Billie Michelle Maynard-Simpson
# Truncating 'former_name' from 37 to 30 chars: Lakaisha Katheene Wiley (Former Name)
# Truncating 'former_name' from 31 to 30 chars: Brenda Gail Jones (Former Name)
# Truncating 'former_name' from 35 to 30 chars: Amanda Daryln Clayton (Former Name)
# Truncating 'former_name' from 37 to 30 chars: Alexandria Diominque White Iezenhafer
# Truncating 'email' from 55 to 50 chars: messenger200320032003@yahoo.com; latoyasilcox@yahoo.com
# Truncating 'former_name' from 33 to 30 chars: Ryshina Lorraine Wallace Mchellon
# Truncating 'former_name' from 36 to 30 chars: Josephine Marie Blanco (Former Name)
# Truncating 'former_name' from 33 to 30 chars: Natnya Denese Dickson Mc Williams
# Truncating 'former_name' from 35 to 30 chars: Lataisha Shervon Blackmon Boneparte
# Truncating 'former_name' from 36 to 30 chars: Heather Michelle Fontaine Macdougall
# Truncating 'former_name' from 35 to 30 chars: Ashley Elizabeth Nicholas Krajewski
# Truncating 'former_name' from 34 to 30 chars: Ashley Elaine Creech (Former Name)
# Truncating 'former_name' from 35 to 30 chars: Sanita Denaen Whetsel (Former Name)
# Truncating 'former_name' from 35 to 30 chars: Angela Cavelle Justis El Laachouchi
# Truncating 'former_name' from 31 to 30 chars: Angelyn Marie Garcia-Skiathitis
# Truncating 'former_name' from 32 to 30 chars: Alicia Dometilla Santos Williams
# Truncating 'former_name' from 34 to 30 chars: Janna Elizabeth Andrews Berberovic
# Truncating 'former_name' from 34 to 30 chars: Rachel Nicole Teresi (Former Name)
# Truncating 'former_name' from 32 to 30 chars: Amanda Marjorie Marie Mcallister
# Truncating 'former_name' from 31 to 30 chars: Tracy Stephanie Daisy Patterson
# Truncating 'former_name' from 31 to 30 chars: Jessica Natalia Bermudez- Smith
# Truncating 'former_name' from 33 to 30 chars: Kasha Katrice Hicks (Former Name)
# Truncating 'former_name' from 38 to 30 chars: Tamekqua Michelle Amaker (Former Name)
# Truncating 'former_name' from 31 to 30 chars: Elizabeth Sandidge Beasley Bobo
# Truncating 'former_name' from 33 to 30 chars: Caroline Arlene Elizabeth Baldwin
# Truncating 'former_name' from 40 to 30 chars: Maydell Melissa Roselani Fajardosantiago
# Truncating 'former_name' from 35 to 30 chars: Sheila Whitehead Harrison Leftridge
# Truncating 'former_name' from 32 to 30 chars: Tara Ashley Abboud (Former Name)
# Truncating 'former_name' from 32 to 30 chars: Katrina Beth Pearl (Former Name)
# Truncating 'former_name' from 31 to 30 chars: Cecelia Elaine Peterson-Frazier
# Truncating 'former_name' from 31 to 30 chars: Beverly Patricia Maree-Billings
# Truncating 'former_name' from 31 to 30 chars: Patricia Katherine Vanderworken
# Truncating 'former_name' from 33 to 30 chars: Kimberlee Dawn Christenson Kearns
# Truncating 'former_name' from 31 to 30 chars: Kathleen Delores Marie Stafford
# Truncating 'former_name' from 37 to 30 chars: Bernadette Suzanne Andrasco-Rodriguez
# Truncating 'former_name' from 34 to 30 chars: Jenna Lynn Senkowsky (Former Name)
# Truncating 'former_name' from 32 to 30 chars: Samantha Leigh Commella Robinson
# Truncating 'former_name' from 31 to 30 chars: Jessica Pierina Gutierrez Rolon
# Truncating 'former_name' from 31 to 30 chars: MICHELLE MARCELLINA KARAMITSIOS
# Truncating 'former_name' from 32 to 30 chars: Ashlie Anne Graham (Former Name)
# Truncating 'former_name' from 32 to 30 chars: WILLIAM GERARDO RODRIGUEZ CORREA
# Truncating 'former_name' from 33 to 30 chars: Linda Joyce Brenner (Former Name)
# Truncating 'former_name' from 32 to 30 chars: Nicole Andrea Phillips-Langabeer
# Truncating 'former_name' from 31 to 30 chars: Carolinie Michelle De La Rionda
# Truncating 'former_name' from 32 to 30 chars: Jasmine Elizabeth Yemiko Stanley
# Truncating 'former_name' from 32 to 30 chars: Shaneika Lashaun Shenaa Ferguson
# Truncating 'former_name' from 31 to 30 chars: Constance Makista Larynn Ingram
# Truncating 'former_name' from 33 to 30 chars: Arielle Constance Charlae Widgeon
# Truncating 'former_name' from 32 to 30 chars: Antonisha Latrese Davon Williams
# Truncating 'former_name' from 34 to 30 chars: Tabitha Lynn Shelley (Former Name)
# Truncating 'former_name' from 32 to 30 chars: Nicole Janina Wein (Former Name)
# Truncating 'former_name' from 32 to 30 chars: Tashna Patrice Cunningham Nathan
# Truncating 'former_name' from 33 to 30 chars: Jordan Chelsea Anna-Marie Hausler
# Truncating 'former_name' from 31 to 30 chars: Angela Densie Flanagan-Williams
# Truncating 'former_name' from 34 to 30 chars: Christina Marie Gallet De St Aurin
# Truncating 'former_name' from 34 to 30 chars: Erica Elaine Glisson (Former Name)
# Truncating 'former_name' from 31 to 30 chars: ASHLEY MARIE ZIMMERMAN RUSHFORD
# Truncating 'former_name' from 36 to 30 chars: Kimberly Joanne Musselwhite (Former)
# Truncating 'former_name' from 36 to 30 chars: Ciprian Mihai Bucataru (Former Name)
# Truncating 'former_name' from 38 to 30 chars: Alexis Mackenzie Maddern (Former Name)
# Truncating 'former_name' from 36 to 30 chars: Ashleigh Sierra Danyelle T Blackwell
# Truncating 'former_name' from 31 to 30 chars: Christopher James Carl Sorensen
# Truncating 'former_name' from 36 to 30 chars: Anna Elizabeth Kendall (Former Name)
# Truncating 'former_name' from 31 to 30 chars: Nettie Elizabeth Wiggins-Fesler
# Truncating 'former_name' from 32 to 30 chars: William  Anthony Carraher-Stross
# Truncating 'former_name' from 32 to 30 chars: Sara Milianette Rivera Rodriguez
# Truncating 'former_name' from 35 to 30 chars: Meagan Elizabeth Ashley Hilderbrand
# Truncating 'former_name' from 31 to 30 chars: GRETCHEN EKISABETH MARIE KASTER
# Truncating 'former_name' from 35 to 30 chars: MARKITTA ANTONENETTE SCARLETT-SNEED
# Truncating 'former_name' from 34 to 30 chars: Georgia Jessica Paul (Former Name)
# Truncating 'former_name' from 31 to 30 chars: Sequoya Joshulyn Hooks Morrison
# Truncating 'former_name' from 34 to 30 chars: Hadijat-Kuburat Oluwatoyin Awosola
# Truncating 'former_name' from 33 to 30 chars: Jillian Kimberly Weinstein-Medure
# Truncating 'former_name' from 33 to 30 chars: Joyess Jonte' Dashanette Anderson
# Truncating 'former_name' from 31 to 30 chars: Vivian Elizabeth Smith-Fountain
# Truncating 'former_name' from 38 to 30 chars: Tarvia Laquenta Shanice Lee Currithers
# Truncating 'former_name' from 32 to 30 chars: Trishaunna Laquel Suddreth Cohen
# Truncating 'former_name' from 31 to 30 chars: Sigurros Johanna Goddard Pruitt
# Truncating 'former_name' from 31 to 30 chars: Stella Maris Natalia Tinnirello
# Truncating 'former_name' from 32 to 30 chars: Alexandra Sylvia Jangrell-Bratli
# Truncating 'former_name' from 31 to 30 chars: Maureen Michelle Rios-Rodriguez
# Truncating 'former_name' from 36 to 30 chars: Sara Alexandra Hardman (Former Name)
# Truncating 'former_name' from 33 to 30 chars: Samantha Lee Martin (Former Name)
# Truncating 'former_name' from 31 to 30 chars: Catherine Grace Bradley Trimble
# Truncating 'former_name' from 35 to 30 chars: HOLLOWAY JONATHAN-CHADSWORTH SAMUEL
# Truncating 'former_name' from 36 to 30 chars: Jewel Lacretia Nigheria Fulton-Hicks
# Truncating 'former_name' from 37 to 30 chars: Brittany Nicole Edwards (Former Name)
# Truncating 'former_name' from 34 to 30 chars: Michelle Leondra Anjanette Johnson
# Truncating 'former_name' from 32 to 30 chars: Samantha Monea' Rodriguez O'Neal
# Truncating 'former_name' from 31 to 30 chars: Brittany Krystal Michelle Wyatt
# Truncating 'former_name' from 32 to 30 chars: Brindusa Simona Catlui-Patterson
# Truncating 'former_name' from 34 to 30 chars: Patricia Elaine Michelle Arrington
# Truncating 'former_name' from 32 to 30 chars: Avionnie Detrayhia Shawnta Moore
# Truncating 'former_name' from 38 to 30 chars: Krystina Suzanne Banyash (Former Name)
# Truncating 'former_name' from 34 to 30 chars: MICHAEL ANTONIO PELLEGRINO IURETIG
# Truncating 'former_name' from 37 to 30 chars: TALIA CHRYSTENE THOMLEY (FORMER NAME)
# Truncating 'former_name' from 34 to 30 chars: Aubree Renee Kuuipo Degrate-Abihai
# Truncating 'former_name' from 35 to 30 chars: DEMETRIA ANTOINETTE MECHELE REDDICK
# Truncating 'former_name' from 33 to 30 chars: Lisa Leigh Moncrief (Former Name)
# Truncating 'former_name' from 36 to 30 chars: Naomi Bernardette Arrendondo-Vidalez
# Truncating 'former_name' from 32 to 30 chars: JENNIFER  MARIE PAPACHARALAMBOUS
# Truncating 'former_name' from 31 to 30 chars: Courtney Elizabeth Link Jarrell
# Truncating 'former_name' from 35 to 30 chars: Kelsea Kendall Ingram (Former Name)
# Truncating 'former_name' from 31 to 30 chars: Bernadette Carmen Lydia Fleming
# Truncating 'former_name' from 33 to 30 chars: Ma Criselda Jerrine Sabado Lumbra
# Truncating 'former_name' from 33 to 30 chars: WILLIAM ALEXANDER FRANKLIN THOMAS
# Truncating 'former_name' from 40 to 30 chars: Camemisha Nicole Strauther (Former Name)
# Truncating 'former_name' from 34 to 30 chars: Jemsand Sapphire Tatiana Mattingly
# ...
# Truncating 'former_name' from 32 to 30 chars: Ingrid Yamileth Good-Mclaughling
# Truncating 'former_name' from 33 to 30 chars: CHRISTOPHER ERIC DARNELL THORNTON
# Truncating 'former_name' from 36 to 30 chars: Nicole Louise Arielle Sampier-Coraci
# Truncating 'former_name' from 35 to 30 chars: Omodele Adetokunbo Olubunmi Sobanjo
# Truncating 'former_name' from 32 to 30 chars: Yecelia Cristalie Colon Figueroa
# Truncating 'former_name' from 31 to 30 chars: LISA-MARIE  KARISSA APRIL FUSCO
# Truncating 'former_name' from 31 to 30 chars: Amanda Lee Nathan Taylor-Parker
# Truncating 'former_name' from 31 to 30 chars: BLANCA KRYSTAL MAERCADO-RAMIREZ
# Truncating 'former_name' from 33 to 30 chars: MICHELLE MARIE STEPHENSON SANCHEZ
# Truncating 'former_name' from 33 to 30 chars: EMELINDA ROSARIO BASILIO-PARRILLA
# Truncating 'former_name' from 32 to 30 chars: Carissa Cassandra Justalyn Keith
# Truncating 'former_name' from 32 to 30 chars: KENNETH ROBERT FREDERICK STEVENS
# Truncating 'former_name' from 34 to 30 chars: Alexandra Morgan Brittany Boutwell
# Truncating 'former_name' from 35 to 30 chars: Brandon Michael Rousseau Farrington
# Truncating 'former_name' from 33 to 30 chars: Charlene Denise Da Souza-Aristide
# Truncating 'former_name' from 31 to 30 chars: Courtney Michelle De Los Santos
# Truncating 'former_name' from 33 to 30 chars: Andrew Anthony Ernest  Or  Earnst
# Truncating 'former_name' from 33 to 30 chars: Sharon Richards Hernandez Jiminez
# Truncating 'former_name' from 31 to 30 chars: Charlene Rene Mcalpin Chambliss
# Truncating 'former_name' from 33 to 30 chars: MANUEL MIGUEL FITZGERALD-PALACIOS
# Truncating 'former_name' from 31 to 30 chars: MONIQUE ANDREA-LA SHONNA KEARSE
# Truncating 'former_name' from 34 to 30 chars: Virna Loraine Villalobos-Bartleson
# Truncating 'former_name' from 33 to 30 chars: CHRISTOPHER HARRISONPHILLIP SPEAR
# Truncating 'former_name' from 31 to 30 chars: Mary Elizabeth Williams Wallace
# Truncating 'former_name' from 31 to 30 chars: Chelsea Micaela Elyse Kilhoffer
# Truncating 'former_name' from 31 to 30 chars: COLETTE ANN VERSACE WESTERWATER
# Truncating 'former_name' from 31 to 30 chars: Maria Christine Wellington Soto
# Truncating 'former_name' from 31 to 30 chars: EDIL ROBERTO MALDONADO SANOGUET
# Truncating 'former_name' from 32 to 30 chars: SHAMEYAH SHAUNYA CADESHA FRANCIS
# Truncating 'former_name' from 33 to 30 chars: Gabriel Stefano Gonzales-Portillo
# Truncating 'former_name' from 32 to 30 chars: Cesiash Betsabe Legarreta Cortes
# Truncating 'former_name' from 31 to 30 chars: CAROLOS LUIS BUITRAGO MALDONADO
# Truncating 'former_name' from 34 to 30 chars: Caroline Marie Del Rocio Hettinger
# Truncating 'former_name' from 31 to 30 chars: Suzanne Michelle Kokinda Murray
# Truncating 'former_name' from 31 to 30 chars: Tiffany Camille Ciara Blackburn
# Truncating 'former_name' from 31 to 30 chars: Cristina Isabel Galarza Mercado
# Truncating 'former_name' from 34 to 30 chars: Mixila Stephanie Moreales Alvarado
# Truncating 'former_name' from 31 to 30 chars: Tytanya Nikkita Sheilice Knight
# Truncating 'former_name' from 31 to 30 chars: Gloria Margarita Rodriguez Mena
# Truncating 'former_name' from 31 to 30 chars: Josue Plinid Morrobel Rodriguez
# Truncating 'former_name' from 34 to 30 chars: SHAKIRA MICHELLE CAMPBELL-WILLIAMS
# Truncating 'former_name' from 32 to 30 chars: DELSA MARGARITA DUARE VILLALOBOS
# Truncating 'former_name' from 31 to 30 chars: Lyudmila Plamenova Haralampieva
# Truncating 'former_name' from 32 to 30 chars: Monnette Elizabeth Kloor-Coppola
# Truncating 'former_name' from 34 to 30 chars: Mahbubor Rasul Mohammed Ahsanullah
# Truncating 'former_name' from 37 to 30 chars: Maria Christina Flor Baldevia Perales
# Truncating 'former_name' from 40 to 30 chars: Darrell Dean Kane  Was   Lueken   Leuhen
# Truncating 'former_name' from 37 to 30 chars: Anne Stephanie Rakoczy-Kostrycky-Zwil
# Truncating 'former_name' from 31 to 30 chars: Natalya Aleksandrovna Korotkova
# Truncating 'former_name' from 31 to 30 chars: Christiana Michelle Landskroner
# Truncating 'former_name' from 34 to 30 chars: Externann (Typo On The Voter Card)
# Truncating 'former_name' from 31 to 30 chars: JEFFERSON JOSEPH BLANTON-HARRIS
# Truncating 'former_name' from 33 to 30 chars: Kimberly Renee Carberry Gilchrist
# Truncating 'former_name' from 40 to 30 chars: Sara Victoria Amalia M Rosenberger-Fudge
# Truncating 'former_name' from 31 to 30 chars: SUZANNE MICHELE ALSTRIN-GADBOIS
# Truncating 'former_name' from 34 to 30 chars: FONTELLA DENISE MITHCELL DECOURSEY
# Truncating 'former_name' from 31 to 30 chars: Louie Anthony Mangawan Tiongson
# Truncating 'former_name' from 38 to 30 chars: Christopher Frederico Ogand O Ferreira
# Truncating 'former_name' from 32 to 30 chars: SHAEMMIT TODDAI RAVEEEN ANDERSON
# Truncating 'former_name' from 33 to 30 chars: Brittany Lorraine Padgette-Catley
# Truncating 'former_name' from 32 to 30 chars: Annette Marie Corchado Villafane
# Truncating 'former_name' from 31 to 30 chars: Hadassah Patricia Knowles Green
# Truncating 'former_name' from 37 to 30 chars: TAMARA EBONY SIMONE LANCASTER-MCQUEEN
# Truncating 'former_name' from 36 to 30 chars: Natasha Gabriella Rimmington-Sambria
# Truncating 'former_name' from 31 to 30 chars: Diamel Altagracia De Leon Munoz
# Truncating 'former_name' from 32 to 30 chars: Destiny L'Asia Domunique Jackson
# Truncating 'former_name' from 32 to 30 chars: Andres Manuel Villanueva Vazquez
# Truncating 'former_name' from 31 to 30 chars: Zoe Yamilet De La Torre Fundora
# Truncating 'former_name' from 31 to 30 chars: Sangeetha Chakkungal Giridharan
# Truncating 'former_name' from 33 to 30 chars: ALISON BURGESS KARNISKI CULLINANE
# Truncating 'former_name' from 32 to 30 chars: Colleen Michelle Heffern-Perusse
# Truncating 'former_name' from 31 to 30 chars: Christine Marie Murphy Bassaber
# Truncating 'former_name' from 31 to 30 chars: Rebecca Ann Reichwald Mcsweeney
# Truncating 'former_name' from 31 to 30 chars: Cassandra Anita Maynardknighten
# Truncating 'former_name' from 31 to 30 chars: Katherine Roemelen Rigsby Davis
# Truncating 'former_name' from 31 to 30 chars: David James Willett-Townsend Jr
# Truncating 'former_name' from 31 to 30 chars: Felecia Haiku Monique Mccormick
# Truncating 'former_name' from 32 to 30 chars: PAMELA AURIMARIE  VISALDEN ORTIZ
# Truncating 'former_name' from 33 to 30 chars: ZULEIKA IVELISSE SANTIAGO MORALES
# Truncating 'former_name' from 32 to 30 chars: BEATRIC SAINT JULIS SAINT JUSTIN
# Truncating 'former_name' from 31 to 30 chars: Briana Michelle Carter Pompilus
# Truncating 'former_name' from 32 to 30 chars: Joseph Neubert Arvin Campbell Jr
# Truncating 'former_name' from 31 to 30 chars: Yolanda Jascinth Heather Brewer
# Truncating 'former_name' from 31 to 30 chars: Darlene Louise Demase-Slaughter
# Truncating 'former_name' from 31 to 30 chars: John Joseph Rodriguez De La Paz
# Truncating 'former_name' from 33 to 30 chars: RAFAEL ANTONIO CONTREVAS MARTINEZ
# Truncating 'former_name' from 31 to 30 chars: Patrick Michael Woodcock-Murphy
# Truncating 'former_name' from 33 to 30 chars: Sofia Gabriela Guartatanga Romero
# Truncating 'former_name' from 32 to 30 chars: GERARDO ENRIQUE PLANAS VELAZQUEZ
# Truncating 'former_name' from 31 to 30 chars: Stephanie Denise Cassandra Burt
# Truncating 'former_name' from 32 to 30 chars: Brianne Mauriaunte'Deshawn Curry
# Truncating 'former_name' from 33 to 30 chars: Jo Nytranna Dyjasha Tyshina Young
# Truncating 'former_name' from 36 to 30 chars: Rafael Enrique Daniel Trovato-Cuesta
# Truncating 'former_name' from 36 to 30 chars: Chon Danielle  Raylin Hardage  Denny
# Truncating 'former_name' from 31 to 30 chars: CHRISTINE CLAIRE VAN DEYAR-WISE
# Truncating 'former_name' from 32 to 30 chars: NORMAN WASHINGTON MICHAEL CLARKE
# Truncating 'former_name' from 31 to 30 chars: CARRETT AUSTIN PATRICK WINBERRY
# Truncating 'former_name' from 31 to 30 chars: RAQUEL ALTAGRACIA VALDEZ PINEDA
# Truncating 'former_name' from 31 to 30 chars: Francisco Antonio Portella Pena
# Truncating 'former_name' from 35 to 30 chars: Maribel Margarita Ortiz Ortega Lara
# Truncating 'former_name' from 31 to 30 chars: RICHARD MANUEL PUCHALES PRUNEDA
# Truncating 'former_name' from 34 to 30 chars: ALEJANDRO MANUEL CORONADO GONZALEZ
# Truncating 'former_name' from 34 to 30 chars: RICHARD GIOVANNI VALDIVIESO MACIAS
# Truncating 'former_name' from 31 to 30 chars: Jennifer Christie Suarez Jankes
# Truncating 'former_name' from 33 to 30 chars: Carlos Antonio Concepcion Padilla
# Truncating 'former_name' from 31 to 30 chars: Kristina Pappas Bristol-Buckley
# Truncating 'former_name' from 36 to 30 chars: KATHERINE MARIE OQUIST DE VALDIVIESO
# Truncating 'former_name' from 31 to 30 chars: VINCENT JOSEPH RYAN MAGUIRE III
# Truncating 'former_name' from 32 to 30 chars: Rogelio Ernesto Molina-Hernandez
# Truncating 'former_name' from 38 to 30 chars: Ferrolyn Annasteese Hightower Thompson
# Truncating 'former_name' from 32 to 30 chars: VICTOR IVAN OLUFEMI LINDE DUNCAN
# Truncating 'former_name' from 32 to 30 chars: Rhodrikia Vanquita O'shea Samson
# Truncating 'former_name' from 33 to 30 chars: Jesus Mnauel Carrasquillo Rosario
# Truncating 'former_name' from 34 to 30 chars: Denae Mercedes Marquette Remington
# Truncating 'former_name' from 32 to 30 chars: Barbara Irene Montende Rodriguez
# Truncating 'former_name' from 31 to 30 chars: Josephine Ann Tomasine-Elstrodt
# Truncating 'former_name' from 33 to 30 chars: Shannon Triplett Leade Poindexter
# Truncating 'former_name' from 31 to 30 chars: Name Is Incorrect On Voter Card
# Truncating 'former_name' from 32 to 30 chars: Brianna Shandrell Maria Thompson
# Truncating 'former_name' from 32 to 30 chars: MATTEW EMAUEL KAUTZMAN-SCHAEFFER
# Truncating 'former_name' from 32 to 30 chars: Edrick Rafael Martinez Rodriguez
# Truncating 'former_name' from 31 to 30 chars: Christina Tammera Rheanea Toney
# Truncating 'former_name' from 38 to 30 chars: Zakiyyah Iman Maarij Bint Abdel Jaleel
# Truncating 'former_name' from 35 to 30 chars: Cahterine Elizabeth Patacsil-Healey
# Truncating 'former_name' from 33 to 30 chars: Charleen Elizabeth Lazzara Burgio
# Truncating 'former_name' from 36 to 30 chars: Carlos Juan Avelino Quintana Cintron
# Truncating 'former_name' from 31 to 30 chars: Nora M Garrido Lobo De Scheffey
# Truncating 'former_name' from 31 to 30 chars: Shaquitta Marqeia De'Yon Joyner
# Truncating 'former_name' from 31 to 30 chars: Carlos Gabriel Cestero Santiago
# Truncating 'former_name' from 32 to 30 chars: Kenneth Michaelovich Zenfeldmann
# Truncating 'former_name' from 31 to 30 chars: Maria Mercedes Rivera Feliciano
# Truncating 'former_name' from 32 to 30 chars: Kassandra Solangie Holuino-Perez
# Truncating 'former_name' from 32 to 30 chars: Delphine Lovorn Gwendolyn Joseph
# Truncating 'former_name' from 34 to 30 chars: Natalia Michelle Camacho Hernandez
# Truncating 'former_name' from 31 to 30 chars: Lorena Virginia Lopez Hernandez
# Truncating 'former_name' from 31 to 30 chars: Francisco Javier Junco Zequeira
# Truncating 'former_name' from 34 to 30 chars: LINDSAY EUNICE NICOLE MOORE STREET
# Truncating 'former_name' from 31 to 30 chars: Rebecca Rose Gerhardstein Nader
# Truncating 'former_name' from 32 to 30 chars: CHRISTI JANET CATALDO-MAUZEROLLE
# Truncating 'former_name' from 33 to 30 chars: Lillian Gertrude Burgess-Keffalas
# Truncating 'former_name' from 33 to 30 chars: Francine Marie Alvarez-Baccarella
# Truncating 'former_name' from 31 to 30 chars: Kimberly Ann Springsteen-Abbott
# Truncating 'former_name' from 31 to 30 chars: Jessica Lynn Day (Phetterplace)
# Truncating 'former_name' from 35 to 30 chars: Glara Guadalupe Rodriguez Hernandez
# Truncating 'former_name' from 33 to 30 chars: JENNIFER FRANCES LIVORNESE-WHALEN
# Truncating 'former_name' from 31 to 30 chars: Kristie Marie Bartlett Tijerina
# Truncating 'former_name' from 32 to 30 chars: BRANDI SAVANNAH FINNESY-MCINTIRE
# Truncating 'former_name' from 31 to 30 chars: Johnathan Christian-Lee Frazier
# Truncating 'former_name' from 31 to 30 chars: VERONICA JOYCE WANAMAKER MILLER
# Truncating 'former_name' from 31 to 30 chars: Lillian Evelyn Santiago Guevara
# Truncating 'former_name' from 31 to 30 chars: Deborah Lynn Mangiofico-Coppola
# Truncating 'former_name' from 31 to 30 chars: Bethany Carol Clarke-Rospierski
# Truncating 'former_name' from 40 to 30 chars: Rosamaria Macolata Gagliarso-Dispasquale
# Truncating 'former_name' from 31 to 30 chars: Kimberly Suzanne Cornell Barbie
# Truncating 'former_name' from 34 to 30 chars: Michelle Verniece Poole-Schwappach
# Truncating 'former_name' from 33 to 30 chars: DACIA TROMBETTA NURICUMBO ANGELES
# Truncating 'former_name' from 31 to 30 chars: Stephanie Michelle Rosa-Marrero
# Truncating 'former_name' from 34 to 30 chars: Katharine Alicia Bentham Mcfarland
# Truncating 'former_name' from 31 to 30 chars: Angel Rafael Gonzalez Rodriguez
# Truncating 'former_name' from 31 to 30 chars: Susan Elizabeth Dovhey-Phillips
# Truncating 'former_name' from 31 to 30 chars: Militza Gutierrez Torres-Shirey
# Truncating 'former_name' from 33 to 30 chars: Elizabeth Marie Payment Schoppman
# Truncating 'former_name' from 33 to 30 chars: Middle Initial Should Be L, Not T
# Truncating 'former_name' from 33 to 30 chars: Kathrina Annette Washington-Woods
# Truncating 'former_name' from 32 to 30 chars: Ingris Marilin Iraheta-Gavilanes
# Truncating 'former_name' from 33 to 30 chars: Cindy Christine Guerrero Gonzalez
# Truncating 'former_name' from 34 to 30 chars: Brittany Jo-Ann James (Belevender)
# Truncating 'former_name' from 32 to 30 chars: Chantal Andree Claudine Ellerbee
# Truncating 'former_name' from 40 to 30 chars: Dammika Kariyawasam Kariyawasam Puwakpit
# Truncating 'former_name' from 31 to 30 chars: Manuela Astrid Lagardere-Erdody
# Truncating 'former_name' from 33 to 30 chars: Michelle Teresa Irizarry Melendez
# Truncating 'former_name' from 32 to 30 chars: Ekaterina Valentinova Atanassova
# Truncating 'former_name' from 33 to 30 chars: Lourin Veronicas Steele-Vangorder
# Truncating 'former_name' from 31 to 30 chars: JENNIFER ANN SEGURA ALBINAGORTA
# Truncating 'former_name' from 31 to 30 chars: Bailey Darlene Thomas Westbrook
# Truncating 'former_name' from 31 to 30 chars: Daiquiri Ann Michelle Neutzling
# Truncating 'former_name' from 34 to 30 chars: Ashley Eilzabeth Marie Archambault
# Truncating 'former_name' from 31 to 30 chars: Alicia Marilyn Hojara Stevenson
# Truncating 'former_name' from 33 to 30 chars: Nicole Oliveira Mendonca Ferreira
# Truncating 'former_name' from 34 to 30 chars: ADEBISI ELIZABETH WILLIAMS OREMOSU
# Truncating 'former_name' from 32 to 30 chars: Michelle Paulette Walter Albaugh
# Truncating 'former_name' from 31 to 30 chars: Carmen Milagros D'Acosta Burgos
# Truncating 'former_name' from 33 to 30 chars: Danielle Fredrica Monique Dillard
# Truncating 'former_name' from 34 to 30 chars: Miriam Noami Barrett Cramer Fisher
# Truncating 'former_name' from 31 to 30 chars: MICHAEL KENNETH JOSEPH LACHANCE
# Truncating 'former_name' from 31 to 30 chars: Caralyne Evelyn Gabriella Jahns
# Truncating 'former_name' from 31 to 30 chars: Kristen Leigh Johnson-Tallitsch
# Truncating 'former_name' from 31 to 30 chars: IVAN GIOVANIE ROSALES HERNANDEZ
# Truncating 'former_name' from 32 to 30 chars: DOMINIQUE MICHELLE BACA-LOMANITZ
# Truncating 'former_name' from 31 to 30 chars: Yaina Izamar Marrero Betancourt
# Truncating 'former_name' from 33 to 30 chars: Ricardo David Maldonado Rodriguez
# Truncating 'former_name' from 31 to 30 chars: Cristian Charles Jason Toellner
# Truncating 'former_name' from 34 to 30 chars: To Correct Spelling Of Middle Name
# Truncating 'former_name' from 32 to 30 chars: SAN JUANA RODRIGUEZ DE CASTANEDA
# Truncating 'former_name' from 31 to 30 chars: KRISTOPHER MICHAEL LEE HOLLOWAY
# Cleaned file saved at: /Users/borismartinez/Documents/final/VoterRegistration_combined_date_cleaned.txt
# Attempting to connect...
# Connected to PostgreSQL
# Connected to PostgreSQL. Uploading '/Users/borismartinez/Documents/final/VoterRegistration_combined_date.txt' to 'voterfile.election_detail_2016'.
# Successfully uploaded data from '/Users/borismartinez/Documents/final/VoterRegistration_combined_date_cleaned.txt' using COPY.
# Database connection closed.

# %% [markdown]
# # Improvements for V1.1

# %% [markdown]
# - Scalable `.txt` merge; Instead of processing only 2 directories and 1 output file let's allow for multiple directories and designated filename
# - `connect_db()` figure a way to anonymize database connection
# - Table creation - documentation edits
# - `clean_value` - Additional cleaning rules for efficient disk allication
# - Need to ensure that window pathway works as well. Also account for spaces in folder name
# - `upload_txt_postgres` take table name as parameter
# - Need a log system to save malformed rows for manual fixing workflow my voter_id 122264925
